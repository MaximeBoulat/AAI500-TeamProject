# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('Datasets/Credit.csv')

display(df)

# draw a histogram of the data

# another test
# Tanya test

print("Beakal Tets commit")
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]
# Beakal Tets commit

# %%
df.shape
# Out:
# (30000, 25)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset -- Skip first metadata row
df = pd.read_csv('Datasets/Credit.csv')

# Drop the ID column as it's not useful for analysis
df_cleaned = df.drop(columns=["ID"])

# Set Seaborn style
sns.set(style="whitegrid")

# Generating Correlation Heatmap
plt.figure(figsize=(18, 14))
correlation_matrix = df_cleaned.corr()
sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# Printing my explanation
print("explanation")
print()
print("The correlation heatmap of the dataset reveals relationships between features such as: High correlation among BILL_AMT variables (e.g., BILL_AMT1, BILL_AMT2, etc.)")
print("The correlation heatmap also indicates a positive correlation between LIMIT_BAL and PAY_AMT values, a Mmoderate positive correlation between past payment statuses (PAY_0 to PAY_6) and default likelihood")
# Out:
# explanation
#
# The correlation heatmap of the dataset reveals relationships between features such as: High correlation among BILL_AMT variables (e.g., BILL_AMT1, BILL_AMT2, etc.)
# The correlation heatmap also indicates a positive correlation between LIMIT_BAL and PAY_AMT values, a Mmoderate positive correlation between past payment statuses (PAY_0 to PAY_6) and default likelihood

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset (assuming the file is in the same directory) --Skip first metadata row
df = pd.read_csv('Datasets/Credit.csv')

# Drop the ID column as it's not useful for analysis
df_cleaned = df.drop(columns=["ID"])

# Set Seaborn style
sns.set(style="whitegrid")

# --- Histogram of Credit Limit ---
plt.figure(figsize=(10, 6))
sns.histplot(df_cleaned["LIMIT_BAL"], bins=30, kde=True, color="skyblue")
plt.title("Distribution of Credit Limit (LIMIT_BAL)")
plt.xlabel("Credit Limit")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# Printing my explanation
print("Explanation -- The histogram of the credit limit (LIMIT_BAL)")
print()
print("Most credit limits are concentrated below 200,000 units.")
print("The distribution is right-skewed, indicating a smaller number of clients with very high credit limits.")
# Out:
# Explanation -- The histogram of the credit limit (LIMIT_BAL)
#
# Most credit limits are concentrated below 200,000 units.
# The distribution is right-skewed, indicating a smaller number of clients with very high credit limits.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('Datasets/Credit.csv')
df = df.drop(columns=["ID"])

# Create AGE groups
age_bins = [20, 30, 40, 50, 60, 70, 80]
age_labels = ['20s', '30s', '40s', '50s', '60s', '70s']
df['AGE_GROUP'] = pd.cut(df['AGE'], bins=age_bins, labels=age_labels, right=False)

# Define population segments
segment_columns = ['SEX', 'EDUCATION', 'MARRIAGE', 'AGE_GROUP']
segment_group = df.groupby(segment_columns)

# Count total and on-time payments per segment
segment_stats = segment_group['default payment next month'].agg(
    total='count',
    on_time=lambda x: (x == 0).sum()
).reset_index()

# Calculate P(On-time | Segment)
segment_stats['P_on_time_given_segment'] = segment_stats['on_time'] / segment_stats['total']

# Sort segments by highest probability
segment_stats_sorted = segment_stats.sort_values(by='P_on_time_given_segment', ascending=False)

# Create readable segment labels
segment_stats_sorted['Segment'] = (
    "SEX=" + segment_stats_sorted['SEX'].astype(str) +
    ", EDU=" + segment_stats_sorted['EDUCATION'].astype(str) +
    ", MARR=" + segment_stats_sorted['MARRIAGE'].astype(str) +
    ", AGE=" + segment_stats_sorted['AGE_GROUP'].astype(str)
)

# Plot top 10 segments
plt.figure(figsize=(12, 6))
sns.barplot(data=segment_stats_sorted.head(10), 
            x='P_on_time_given_segment', 
            y='Segment', 
            palette='viridis')
plt.xlabel("P(On-time Payment | Segment)")
plt.ylabel("Population Segment")
plt.title("Top 10 Segments Most Likely to Pay On Time")
plt.tight_layout()
plt.show()


# Printing my explanation
print("Explanation -- Bayes’ Theorem to predict which population segment is most likely to pay their credit card bills on time")
print()
print("Calculates likelihood of on-time payment per segment using a Bayesian logic.")
print("Displays the top 10 most reliable segments to pay there credit on time.")
# Out:
# C:\Users\beaka\AppData\Local\Temp\ipykernel_16004\1542034703.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   segment_group = df.groupby(segment_columns)
# C:\Users\beaka\AppData\Local\Temp\ipykernel_16004\1542034703.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=segment_stats_sorted.head(10),
# Explanation -- Bayes’ Theorem to predict which population segment is most likely to pay their credit card bills on time
#
# Calculates likelihood of on-time payment per segment using a Bayesian logic.
# Displays the top 10 most reliable segments to pay there credit on time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('Datasets/Credit.csv')
df = df.drop(columns=["ID"])

# Create AGE groups
age_bins = [20, 30, 40, 50, 60, 70, 80]
age_labels = ['20s', '30s', '40s', '50s', '60s', '70s']
df['AGE_GROUP'] = pd.cut(df['AGE'], bins=age_bins, labels=age_labels, right=False)

# Define population segments
segment_columns = ['SEX', 'EDUCATION', 'MARRIAGE', 'AGE_GROUP']
segment_group = df.groupby(segment_columns)

# Count total and on-time payments per segment
segment_stats = segment_group['default payment next month'].agg(
    total='count',
    on_time=lambda x: (x == 0).sum()
).reset_index()

# Calculate P(On-time Segment)
segment_stats['P_on_time_given_segment'] = segment_stats['on_time'] / segment_stats['total']

# Plot histogram with KDE
plt.figure(figsize=(10, 6))
sns.histplot(segment_stats['P_on_time_given_segment'], bins=20, kde=True, color='skyblue', edgecolor='black')

# Add vertical lines
mean_prob = segment_stats['P_on_time_given_segment'].mean()
max_prob = segment_stats['P_on_time_given_segment'].max()

plt.axvline(mean_prob, color='orange', linestyle='--', linewidth=2, label=f'Mean: {mean_prob:.2f}')
plt.axvline(max_prob, color='green', linestyle='-', linewidth=2, label=f'Max: {max_prob:.2f}')

# Labels and legend
plt.title("Distribution of P(On-time Payment Segment) with KDE")
plt.xlabel("P(On-time Payment Segment)")
plt.ylabel("Number of Segments")
plt.legend()
plt.tight_layout()
plt.show()

# Printing my explanation
print("Explanation: I analyzed the probability distribution of a client being granted a credit loan based on their credibility. While the dataset doesn't explicitly say if a client is -granted-- a loan, we can infer credibility based on the target variable")
print()
print("Plan:Define Credibility: Clients with default payment next month == 0. Analyze how credibility varies with key features (e.g., LIMIT_BAL, PAY_0, AGE, EDUCATION, etc.).Estimate probability:P(Credible Feature) Visualize the probability distribution using a plot (e.g., KDE + Histogram)")
print("This Chart Shows: The likelihood of being a credible client (on-time payer) based on credit limit. It looks like creditworthiness (credibility) shifts with the size of the loan")
# Out:
# C:\Users\beaka\AppData\Local\Temp\ipykernel_16004\297350404.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   segment_group = df.groupby(segment_columns)
# Explanation: I analyzed the probability distribution of a client being granted a credit loan based on their credibility. While the dataset doesn't explicitly say if a client is -granted-- a loan, we can infer credibility based on the target variable
#
# Plan:Define Credibility: Clients with default payment next month == 0. Analyze how credibility varies with key features (e.g., LIMIT_BAL, PAY_0, AGE, EDUCATION, etc.).Estimate probability:P(Credible Feature) Visualize the probability distribution using a plot (e.g., KDE + Histogram)
# This Chart Shows: The likelihood of being a credible client (on-time payer) based on credit limit. It looks like creditworthiness (credibility) shifts with the size of the loan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load and prepare data
df = pd.read_csv('Datasets/Credit.csv')
df = df.drop(columns=["ID"])
df['Credible'] = df['default payment next month'].apply(lambda x: 1 if x == 0 else 0)

# Set plot style
sns.set(style="whitegrid")

# -PLOT : Credibility vs Education 
plt.figure(figsize=(8, 6))
edu_order = sorted(df['EDUCATION'].unique())  # Ensure consistent order
sns.barplot(data=df, x='EDUCATION', y='Credible', estimator=lambda x: x.mean(), order=edu_order, palette="viridis")
plt.title("Probability of Being Credible by Education Level")
plt.xlabel("Education Level (1=Graduate, 2=University, 3=High School, etc.)")
plt.ylabel("P(Credible | Education)")
plt.tight_layout()
plt.show()

print("Explanation -- additional plots that analyze the probability of a client being credible (on-time payer) by: Education level")
print()
print("The Plot shows how credibility varies across education levels. Example: Higher-educated individuals may show higher credibility rates.")
# Out:
# C:\Users\beaka\AppData\Local\Temp\ipykernel_16004\862883616.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='EDUCATION', y='Credible', estimator=lambda x: x.mean(), order=edu_order, palette="viridis")
# Explanation -- additional plots that analyze the probability of a client being credible (on-time payer) by: Education level
#
# The Plot shows how credibility varies across education levels. Example: Higher-educated individuals may show higher credibility rates.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load and prepare data
df = pd.read_csv('Datasets/Credit.csv')
df = df.drop(columns=["ID"])
df['Credible'] = df['default payment next month'].apply(lambda x: 1 if x == 0 else 0)

# Set plot style
sns.set(style="whitegrid")

# PLOT: Credibility vs PAY_0 
plt.figure(figsize=(10, 6))
pay_order = sorted(df['PAY_0'].unique())  # Ensure correct order
sns.barplot(data=df, x='PAY_0', y='Credible', estimator=lambda x: x.mean(), order=pay_order, palette="mako")
plt.title("Probability of Being Credible by PAY_0 Status")
plt.xlabel("Most Recent Payment Status (PAY_0)")
plt.ylabel("P(Credible | PAY_0)")
plt.tight_layout()
plt.show()

print("Explanation -- additional plots that analyze the probability of a client being credible (on-time payer) by: Past payment behavior")
print()
print("The Plot shows typically, lower PAY_0 (e.g., -1 or 0) is equals to better payment history = higher credibility.")
# Out:
# C:\Users\beaka\AppData\Local\Temp\ipykernel_16004\310809140.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='PAY_0', y='Credible', estimator=lambda x: x.mean(), order=pay_order, palette="mako")
# Explanation -- additional plots that analyze the probability of a client being credible (on-time payer) by: Past payment behavior
#
# The Plot shows typically, lower PAY_0 (e.g., -1 or 0) is equals to better payment history = higher credibility.

# %% [markdown]
# # Introduction

# %% [markdown]
# # Data Cleaning/Preparation

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Model Selection

# %% [markdown]
# # Model Analysis

# %% [markdown]
# # Conclusion and Recommendations
